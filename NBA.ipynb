# %% [markdown]
# # **Name** : BALAKRISHNA REDDY

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/NBA_data.csv")
df
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 2         Steven Adams        C   27     27           760.0             0.592
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
#      Threepoint Attempt rate  Free throw attempt rate  \
# 0                      0.000                    0.541
# 1                      0.250                    0.000
# 2                        NaN                    0.397
# 3                      0.015                    0.469
# 4                      0.298                    0.093
# ..                       ...                      ...
# 492                    0.298                    0.346
# 493                    0.104                    0.169
# 494                    0.349                    0.577
# 495                    0.133                    0.242
# 496                    0.007                    0.500
#
#      Player Efficiency Rating
# 0                        15.1
# 1                        -6.9
# 2                        15.9
# 3                        22.7
# 4                        15.2
# ..                        ...
# 492                      16.6
# 493                      18.5
# 494                      22.9
# 495                      18.2
# 496                      20.5
#
# [497 rows x 9 columns]

# %%
df.head()
# Out:
#               Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0   Precious Achiuwa       PF   21     28           408.0             0.599
# 1       Jaylen Adams       PG   24      6            17.0             0.125
# 2       Steven Adams        C   27     27           760.0             0.592
# 3        Bam Adebayo        C   23     26           873.0             0.641
# 4  LaMarcus Aldridge        C   35     18           480.0             0.542
#
#    Threepoint Attempt rate  Free throw attempt rate  Player Efficiency Rating
# 0                    0.000                    0.541                      15.1
# 1                    0.250                    0.000                      -6.9
# 2                      NaN                    0.397                      15.9
# 3                    0.015                    0.469                      22.7
# 4                    0.298                    0.093                      15.2

# %%
df.tail()
# Out:
#              Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 492    Delon Wright       SG   28     28           823.0             0.559
# 493  Thaddeus Young       PF   32     23           592.0             0.597
# 494      Trae Young       PG   22     26           901.0             0.598
# 495     Cody Zeller        C   28     15           361.0             0.569
# 496     Ivica Zubac        C   23     30           586.0             0.722
#
#      Threepoint Attempt rate  Free throw attempt rate  \
# 492                    0.298                    0.346
# 493                    0.104                    0.169
# 494                    0.349                    0.577
# 495                    0.133                    0.242
# 496                    0.007                    0.500
#
#      Player Efficiency Rating
# 492                      16.6
# 493                      18.5
# 494                      22.9
# 495                      18.2
# 496                      20.5

# %%
df.describe()
# Out:
#               Age       Games  Minutes Played  True Shooting(%)  \
# count  497.000000  497.000000      495.000000        494.000000
# mean    25.623742   18.456740      416.492929          0.538939
# std      4.054229    8.311394      297.543620          0.130360
# min     19.000000    1.000000        2.000000          0.000000
# 25%     22.000000   12.000000      127.000000          0.500000
# 50%     25.000000   20.000000      417.000000          0.556000
# 75%     28.000000   26.000000      665.500000          0.607000
# max     37.000000   30.000000     1101.000000          1.500000
#
#        Threepoint Attempt rate  Free throw attempt rate  \
# count               495.000000               495.000000
# mean                  0.406362                 0.274804
# std                   0.234207                 0.270650
# min                   0.000000                 0.000000
# 25%                   0.255000                 0.142000
# 50%                   0.418000                 0.227000
# 75%                   0.566000                 0.318000
# max                   1.000000                 2.667000
#
#        Player Efficiency Rating
# count                497.000000
# mean                  12.646278
# std                    7.404316
# min                  -40.900000
# 25%                    9.300000
# 50%                   12.600000
# 75%                   16.700000
# max                   38.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Player                    497 non-null    object
#  1   Position                  497 non-null    object
#  2   Age                       497 non-null    int64
#  3   Games                     497 non-null    int64
#  4   Minutes Played            495 non-null    float64
#  5   True Shooting(%)          494 non-null    float64
#  6   Threepoint Attempt rate   495 non-null    float64
#  7   Free throw attempt rate   495 non-null    float64
#  8   Player Efficiency Rating  497 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 35.1+ KB

# %%
df.isnull()
# Out:
#      Player  Position    Age  Games  Minutes Played  True Shooting(%)  \
# 0     False     False  False  False           False             False
# 1     False     False  False  False           False             False
# 2     False     False  False  False           False             False
# 3     False     False  False  False           False             False
# 4     False     False  False  False           False             False
# ..      ...       ...    ...    ...             ...               ...
# 492   False     False  False  False           False             False
# 493   False     False  False  False           False             False
# 494   False     False  False  False           False             False
# 495   False     False  False  False           False             False
# 496   False     False  False  False           False             False
#
#      Threepoint Attempt rate  Free throw attempt rate  \
# 0                      False                    False
# 1                      False                    False
# 2                       True                    False
# 3                      False                    False
# 4                      False                    False
# ..                       ...                      ...
# 492                    False                    False
# 493                    False                    False
# 494                    False                    False
# 495                    False                    False
# 496                    False                    False
#
#      Player Efficiency Rating
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 492                     False
# 493                     False
# 494                     False
# 495                     False
# 496                     False
#
# [497 rows x 9 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().values.sum()
# Out:
# 9

# %%
df = df.dropna()
df
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# 5    Ty-Shon Alexander       SG   22      3             8.0             0.000
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
#      Threepoint Attempt rate  Free throw attempt rate  \
# 0                      0.000                    0.541
# 1                      0.250                    0.000
# 3                      0.015                    0.469
# 4                      0.298                    0.093
# 5                      0.333                    0.000
# ..                       ...                      ...
# 492                    0.298                    0.346
# 493                    0.104                    0.169
# 494                    0.349                    0.577
# 495                    0.133                    0.242
# 496                    0.007                    0.500
#
#      Player Efficiency Rating
# 0                        15.1
# 1                        -6.9
# 3                        22.7
# 4                        15.2
# 5                       -11.9
# ..                        ...
# 492                      16.6
# 493                      18.5
# 494                      22.9
# 495                      18.2
# 496                      20.5
#
# [489 rows x 9 columns]

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Player', 'Position', 'Age', 'Games', 'Minutes Played',
#        'True Shooting(%)', 'Threepoint Attempt rate',
#        'Free throw attempt rate', 'Player Efficiency Rating'],
#       dtype='object')

# %%
x = df.iloc[:,2:7]
y = df.iloc[:,8]

# %%
x
# Out:
#      Age  Games  Minutes Played  True Shooting(%)  Threepoint Attempt rate
# 0     21     28           408.0             0.599                    0.000
# 1     24      6            17.0             0.125                    0.250
# 3     23     26           873.0             0.641                    0.015
# 4     35     18           480.0             0.542                    0.298
# 5     22      3             8.0             0.000                    0.333
# ..   ...    ...             ...               ...                      ...
# 492   28     28           823.0             0.559                    0.298
# 493   32     23           592.0             0.597                    0.104
# 494   22     26           901.0             0.598                    0.349
# 495   28     15           361.0             0.569                    0.133
# 496   23     30           586.0             0.722                    0.007
#
# [489 rows x 5 columns]

# %%
y
# Out:
# 0      15.1
# 1      -6.9
# 3      22.7
# 4      15.2
# 5     -11.9
#        ...
# 492    16.6
# 493    18.5
# 494    22.9
# 495    18.2
# 496    20.5
# Name: Player Efficiency Rating, Length: 489, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x, y )

# %%
df.corr(method ='pearson')
# Out:
#                                Age     Games  Minutes Played  \
# Age                       1.000000  0.230471        0.249943
# Games                     0.230471  1.000000        0.866791
# Minutes Played            0.249943  0.866791        1.000000
# True Shooting(%)          0.227937  0.361749        0.332025
# Threepoint Attempt rate   0.120586  0.011927       -0.031901
# Free throw attempt rate  -0.062440 -0.173431       -0.115610
# Player Efficiency Rating  0.169089  0.381773        0.458753
#
#                           True Shooting(%)  Threepoint Attempt rate  \
# Age                               0.227937                 0.120586
# Games                             0.361749                 0.011927
# Minutes Played                    0.332025                -0.031901
# True Shooting(%)                  1.000000                -0.051235
# Threepoint Attempt rate          -0.051235                 1.000000
# Free throw attempt rate           0.190668                -0.355560
# Player Efficiency Rating          0.715131                -0.329767
#
#                           Free throw attempt rate  Player Efficiency Rating
# Age                                     -0.062440                  0.169089
# Games                                   -0.173431                  0.381773
# Minutes Played                          -0.115610                  0.458753
# True Shooting(%)                         0.190668                  0.715131
# Threepoint Attempt rate                 -0.355560                 -0.329767
# Free throw attempt rate                  1.000000                  0.186984
# Player Efficiency Rating                 0.186984                  1.000000

# %%
x.shape
# Out:
# (489, 5)

# %%
y.shape
# Out:
# (489,)

# %%
x_train.shape
# Out:
# (366, 5)

# %%
x_test.shape
# Out:
# (123, 5)

# %%
y_train.shape
# Out:
# (366,)

# %%
y_test.shape
# Out:
# (123,)

# %%
y_test
# Out:
# 68     10.3
# 378    20.9
# 381    15.3
# 371    17.2
# 180    14.2
#        ...
# 6      12.0
# 329    16.4
# 38     24.8
# 72     12.9
# 140    12.7
# Name: Player Efficiency Rating, Length: 123, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train) 
y_pred = model.predict(x_test)
y_pred
# Out:
# array([13.02192375, 17.34401493, 16.65858774, 21.01780797, 15.16720851,
#         3.45773323, 16.76627177,  1.75341974,  9.26558183, 13.3212397 ,
#        10.10183256, 10.7375997 , 11.88306967, 12.21226757, 16.75047886,
#        15.05791153, 14.1099166 , 19.94323969, 18.17190353, -3.23837399,
#        10.71858174,  7.68175906, 10.97622695, 16.30269255, 18.47942635,
#        10.84992477, 19.20116567,  8.96020104,  7.08119965, 23.17098388,
#        12.77258114,  6.77812769, 12.10489377,  8.23277843, -3.00349717,
#        21.69599632, 15.66361175, 12.42588231, 16.61095724,  4.17261375,
#        15.95713317, 14.52504895, 10.85771589, 17.92652608, 20.04547003,
#        16.19624437,  8.44259214, 17.60345063,  7.49464777, 14.37890982,
#        -0.69433745, 10.78106745, 12.88801539, 18.57927723, 17.56552518,
#        10.01496064, 13.96771948, 13.99825845, 17.54383936, 15.29047354,
#        -8.02134184, 16.64810105, 14.99651749, 15.9484023 , 12.89695368,
#        14.43804764,  8.63778689,  1.53627919,  8.43608556, 12.29723728,
#        18.99426224,  9.30053593,  0.15057192,  9.69807416, 18.99204625,
#        14.43466775, 16.88762285, 13.72019636,  8.17565073, 17.28818447,
#        19.66206377, 20.49925407, 12.6056248 , 15.65502889, 13.59767081,
#        11.73473932, 18.12062976, 19.24790812, 20.26465107, 10.49176447,
#        11.50120619, 12.1219419 , 16.83819487, 16.62525222, 23.23866862,
#         5.85380146, 11.94825692,  9.80785799, 10.21438304, 16.93184062,
#        15.99349459, 12.11186446,  7.04317286,  4.20126739, 19.49413998,
#        16.87707459,  8.78088011, 10.91857459,  8.33905738, 14.75407941,
#        15.04570068,  9.67340864,  9.33772036,  2.39658248,  9.72855977,
#        11.7532345 , 17.18183493, 30.58354962, 10.31364645, 16.09726337,
#        18.90557578, 12.59355302,  7.77441437])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7833776635909208

# %%
df1 = pd.DataFrame({'Actual Data':y_test, 'Predicted Data': y_pred})
df1
# Out:
#      Actual Data  Predicted Data
# 68          10.3       13.021924
# 378         20.9       17.344015
# 381         15.3       16.658588
# 371         17.2       21.017808
# 180         14.2       15.167209
# ..           ...             ...
# 6           12.0       10.313646
# 329         16.4       16.097263
# 38          24.8       18.905576
# 72          12.9       12.593553
# 140         12.7        7.774414
#
# [123 rows x 2 columns]

# %%
df
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# 5    Ty-Shon Alexander       SG   22      3             8.0             0.000
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
#      Threepoint Attempt rate  Free throw attempt rate  \
# 0                      0.000                    0.541
# 1                      0.250                    0.000
# 3                      0.015                    0.469
# 4                      0.298                    0.093
# 5                      0.333                    0.000
# ..                       ...                      ...
# 492                    0.298                    0.346
# 493                    0.104                    0.169
# 494                    0.349                    0.577
# 495                    0.133                    0.242
# 496                    0.007                    0.500
#
#      Player Efficiency Rating
# 0                        15.1
# 1                        -6.9
# 3                        22.7
# 4                        15.2
# 5                       -11.9
# ..                        ...
# 492                      16.6
# 493                      18.5
# 494                      22.9
# 495                      18.2
# 496                      20.5
#
# [489 rows x 9 columns]

# %%
#Age & Postion
plt.bar(df['Age'],df['Position'])
# Out:
# <BarContainer object of 489 artists>

# %%
plt.bar(df['Age'],df['Games'])
# Out:
# <BarContainer object of 489 artists>

# %%
plt.plot(df['Age'],df['Games'])

# %%
plt.plot(df['Age'],df['Player Efficiency Rating'])

# %%
plt.bar(df['Age'],df['Player Efficiency Rating'])
# Out:
# <BarContainer object of 489 artists>

# %%
sns.distplot(df['Player Efficiency Rating'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.regplot(x=df['Minutes Played'],y= df['Player Efficiency Rating'])
